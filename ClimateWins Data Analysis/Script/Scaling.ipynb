# %% [markdown]
# This script contains pitch and hit variables from all balls in play in the MLB
# 2021 season. Data was gathered from BaseballSavant.com.

# %% [markdown]
# ## 1. Importing data and libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import os
import sklearn
from sklearn.preprocessing import StandardScaler

# %%
path = r'D:\WORK\Bootcamp\Machine Learning\Achievement 1\Project\Data'

# %%
df = pd.read_csv(os.path.join(path, "Original", 'Dataset-weather-prediction-dataset-processed.csv'))

# %% [markdown]
# # Exploring

# %%
df.head()
# Out:
#        DATE  MONTH  BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  \
# 0  19600101      1                  7               2.1            0.85
# 1  19600102      1                  6               2.1            0.84
# 2  19600103      1                  8               2.1            0.90
# 3  19600104      1                  3               2.1            0.92
# 4  19600105      1                  6               2.1            0.95
#
#    BASEL_pressure  BASEL_global_radiation  BASEL_precipitation  \
# 0           1.018                    0.32                 0.09
# 1           1.018                    0.36                 1.05
# 2           1.018                    0.18                 0.30
# 3           1.018                    0.58                 0.00
# 4           1.018                    0.65                 0.14
#
#    BASEL_snow_depth  BASEL_sunshine  ...  VALENTIA_cloud_cover  \
# 0                 0             0.7  ...                     5
# ...

# %%
df.columns
# Out:
# Index(['DATE', 'MONTH', 'BASEL_cloud_cover', 'BASEL_wind_speed',
#        'BASEL_humidity', 'BASEL_pressure', 'BASEL_global_radiation',
#        'BASEL_precipitation', 'BASEL_snow_depth', 'BASEL_sunshine',
#        ...
#        'VALENTIA_cloud_cover', 'VALENTIA_humidity', 'VALENTIA_pressure',
#        'VALENTIA_global_radiation', 'VALENTIA_precipitation',
#        'VALENTIA_snow_depth', 'VALENTIA_sunshine', 'VALENTIA_temp_mean',
#        'VALENTIA_temp_min', 'VALENTIA_temp_max'],
#       dtype='object', length=170)

# %%
df.shape
# Out:
# (22950, 170)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22950 entries, 0 to 22949
# Columns: 170 entries, DATE to VALENTIA_temp_max
# dtypes: float64(145), int64(25)
# memory usage: 29.8 MB

# %% [markdown]
# # Prepping

# %%
df.reset_index(inplace=True)
df.rename(columns={'index':'id'}, inplace=True)
df.head()
# Out:
#    id      DATE  MONTH  BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  \
# 0   0  19600101      1                  7               2.1            0.85
# 1   1  19600102      1                  6               2.1            0.84
# 2   2  19600103      1                  8               2.1            0.90
# 3   3  19600104      1                  3               2.1            0.92
# 4   4  19600105      1                  6               2.1            0.95
#
#    BASEL_pressure  BASEL_global_radiation  BASEL_precipitation  \
# 0           1.018                    0.32                 0.09
# 1           1.018                    0.36                 1.05
# 2           1.018                    0.18                 0.30
# 3           1.018                    0.58                 0.00
# 4           1.018                    0.65                 0.14
#
#    BASEL_snow_depth  ...  VALENTIA_cloud_cover  VALENTIA_humidity  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22950 entries, 0 to 22949
# Columns: 171 entries, id to VALENTIA_temp_max
# dtypes: float64(145), int64(26)
# memory usage: 29.9 MB

# %% [markdown]
# # 2 Scaling

# %% [markdown]
# ### 2.1 Check for (and handle) missing values

# %%
df.isnull().sum()
# Out:
# id                     0
# DATE                   0
# MONTH                  0
# BASEL_cloud_cover      0
# BASEL_wind_speed       0
#                       ..
# VALENTIA_snow_depth    0
# VALENTIA_sunshine      0
# VALENTIA_temp_mean     0
# VALENTIA_temp_min      0
# VALENTIA_temp_max      0
# Length: 171, dtype: int64

# %%
#eliminate those records that have NaN values
#no NAN found
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (22950, 171)

# %% [markdown]
# ### 2.2 Scaling

# %%
#create scaler object using StandardScaler from sklearn.preprocessing
#StandardScaler assumes data is normally distributed and scales with a distribution
#around 0 and standard deviation of 1. Scaling happens independently with each variable.

scaler = StandardScaler()

# %%
#create new df with scaled data
columns_to_scale = df.columns

# Select the relevant columns from the DataFrame
df_to_scale = df[columns_to_scale]

# Optionally, view the first few rows of the DataFrame to check
df_to_scale.head()
# Out:
#    id      DATE  MONTH  BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  \
# 0   0  19600101      1                  7               2.1            0.85
# 1   1  19600102      1                  6               2.1            0.84
# 2   2  19600103      1                  8               2.1            0.90
# 3   3  19600104      1                  3               2.1            0.92
# 4   4  19600105      1                  6               2.1            0.95
#
#    BASEL_pressure  BASEL_global_radiation  BASEL_precipitation  \
# 0           1.018                    0.32                 0.09
# 1           1.018                    0.36                 1.05
# 2           1.018                    0.18                 0.30
# 3           1.018                    0.58                 0.00
# 4           1.018                    0.65                 0.14
#
#    BASEL_snow_depth  ...  VALENTIA_cloud_cover  VALENTIA_humidity  \
# ...

# %%
# Compare the original vs. scaled data

df.head()
# Out:
#    id      DATE  MONTH  BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  \
# 0   0  19600101      1                  7               2.1            0.85
# 1   1  19600102      1                  6               2.1            0.84
# 2   2  19600103      1                  8               2.1            0.90
# 3   3  19600104      1                  3               2.1            0.92
# 4   4  19600105      1                  6               2.1            0.95
#
#    BASEL_pressure  BASEL_global_radiation  BASEL_precipitation  \
# 0           1.018                    0.32                 0.09
# 1           1.018                    0.36                 1.05
# 2           1.018                    0.18                 0.30
# 3           1.018                    0.58                 0.00
# 4           1.018                    0.65                 0.14
#
#    BASEL_snow_depth  ...  VALENTIA_cloud_cover  VALENTIA_humidity  \
# ...

# %%
# Find columns in df_to_scale that are not in df
missing_columns = df_to_scale.columns.difference(df.columns)

# Display the result
print(missing_columns)
# Out:
# Index([], dtype='object')

# %%
# Remove the first column (index 0) from df cause id serves as the index column
df_to_scale = df.drop(df.columns[0], axis=1)

# Check the updated DataFrame
df_to_scale.head()
# Out:
#        DATE  MONTH  BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  \
# 0  19600101      1                  7               2.1            0.85
# 1  19600102      1                  6               2.1            0.84
# 2  19600103      1                  8               2.1            0.90
# 3  19600104      1                  3               2.1            0.92
# 4  19600105      1                  6               2.1            0.95
#
#    BASEL_pressure  BASEL_global_radiation  BASEL_precipitation  \
# 0           1.018                    0.32                 0.09
# 1           1.018                    0.36                 1.05
# 2           1.018                    0.18                 0.30
# 3           1.018                    0.58                 0.00
# 4           1.018                    0.65                 0.14
#
#    BASEL_snow_depth  BASEL_sunshine  ...  VALENTIA_cloud_cover  \
# 0                 0             0.7  ...                     5
# ...

# %%
df_to_scale.to_pickle(os.path.join(path, "Prepared", 'Data_scaled.pkl'))

# %%
# Export the DataFrame as a CSV
df_to_scale.to_csv(os.path.join(path,"Prepared", 'Data_scaled.csv'))
