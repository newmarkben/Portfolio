# %% [markdown]
# # Importing Data

# %%
# import libraries
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\Oa\Career Foundry\Data'

# %%
df_prods_merged = pd.read_pickle(os.path.join(path, 'Prepared Data', 'ords_prods_merged.pkl'))

# %%
df_prods_merged.shape
# Out:
# (32434212, 14)

# %%
#df_prods_merged['prices'] = df_prods_merged['prices'].replace(99999.0, 4.99)

# %%
#df_prods_merged['prices'] = df_prods_merged['prices'].replace(14900.0, 4.89)

# %%
df = df_prods_merged[:1000000]

# %%
df.shape
# Out:
# (1000000, 14)

# %%
def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# C:\Users\Oa\AppData\Local\Temp\ipykernel_19920\2848743372.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
df['price_range'].value_counts(dropna = False)
# Out:
# price_range
# Mid-range product    673471
# Low-range product    314116
# High range            12413
# Name: count, dtype: int64

# %%
df['prices'].max()
# Out:
# 99999.0

# %%
df.shape
# Out:
# (1000000, 15)

# %%
df_prods_merged.loc[df_prods_merged['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df_prods_merged.loc[(df_prods_merged['prices'] <= 15) & (df_prods_merged['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df_prods_merged.loc[df_prods_merged['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df_prods_merged.shape
# Out:
# (32434212, 16)

# %%
df_prods_merged['price_range_loc'].value_counts(dropna = False)
# Out:
# price_range_loc
# Mid-range product     21890146
# Low-range product     10126384
# High-range product      417682
# Name: count, dtype: int64

# %%
df_prods_merged.head(10)
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2539329        1             1          2                  8
# 2   2539329        1             1          2                  8
# 3   2539329        1             1          2                  8
# 4   2539329        1             1          2                  8
# 5   2398795        1             2          3                  7
# 6   2398795        1             2          3                  7
# 7   2398795        1             2          3                  7
# 8   2398795        1             2          3                  7
# 9   2398795        1             2          3                  7
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                     NaN       14084                  2          0
# ...

# %%
df_prods_merged['order_dow'].value_counts(dropna = False)
# Out:
# order_dow
# 0    6209632
# 1    5665830
# 6    4500246
# 2    4217766
# 5    4209449
# 3    3844096
# 4    3787193
# Name: count, dtype: int64

# %%
result = []

for value in df_prods_merged['order_dow']:
  if value == 0:
    result.append('Busiest day')
  elif value == 4:
    result.append('Least busy')
  else:
    result.append('Regularly busy')

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
df_prods_merged['busiest_days']=result

# %%
df_prods_merged['busiest_day'].value_counts(dropna = False)
# Out:
# busiest_day
# Regularly busy    22437387
# Busiest day        6209632
# Least busy         3787193
# Name: count, dtype: int64

# %% [markdown]
# # Exercise

# %%
df_prods_merged['busiest_days']=result

# %%
df_prods_merged.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2539329        1             1          2                  8
# 2   2539329        1             1          2                  8
# 3   2539329        1             1          2                  8
# 4   2539329        1             1          2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                     NaN       14084                  2          0
# 2                     NaN       12427                  3          0
# 3                     NaN       26088                  4          0
# 4                     NaN       26405                  5          0
#
#                               product_name  aisle_id  department_id  prices  \
# 0                                     Soda        77              7     9.0
# ...

# %%
df_prods_merged = df_prods_merged.drop(columns=['busiest_day'])

# %%
df_prods_merged.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2539329        1             1          2                  8
# 2   2539329        1             1          2                  8
# 3   2539329        1             1          2                  8
# 4   2539329        1             1          2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                     NaN       14084                  2          0
# 2                     NaN       12427                  3          0
# 3                     NaN       26088                  4          0
# 4                     NaN       26405                  5          0
#
#                               product_name  aisle_id  department_id  prices  \
# 0                                     Soda        77              7     9.0
# ...

# %%
df_prods_merged['busiest_days'].value_counts(dropna = False)
# Out:
# busiest_days
# Regularly busy    22437387
# Busiest day        6209632
# Least busy         3787193
# Name: count, dtype: int64

# %%
#

# %% [markdown]
# # Create Busiest Period Of Day

# %%
df_prods_merged['order_hour_of_day'].value_counts(dropna = False)
# Out:
# order_hour_of_day
# 10    2764390
# 11    2738585
# 14    2691563
# 15    2664522
# 13    2663272
# 12    2620800
# 16    2537469
# 9     2456661
# 17    2089452
# 8     1719952
# 18    1637922
# 19    1259382
# 20     977017
# 7      891928
# 21     796362
# 22     634737
# 23     402612
# 6      290770
# 0      218942
# 1      115786
# 5       88057
# 2       69431
# 4       53283
# 3       51317
# Name: count, dtype: int64

# %%
result = []

for value in df_prods_merged['order_hour_of_day']:
  if value == 10:
    result.append('Most orders')
  elif value == 3:
    result.append('Fewest orders')
  else:
    result.append('Average orders')

# %%
result
# Out:
# ['Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
# ...

# %%
result.value_counts(dropna = False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 result.value_counts(dropna = False)
#
# AttributeError: 'list' object has no attribute 'value_counts'

# %%
df_prods_merged['busiest_period_of_day'] = result

# %%
df_prods_merged.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2539329        1             1          2                  8
# 2   2539329        1             1          2                  8
# 3   2539329        1             1          2                  8
# 4   2539329        1             1          2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                     NaN       14084                  2          0
# 2                     NaN       12427                  3          0
# 3                     NaN       26088                  4          0
# 4                     NaN       26405                  5          0
#
#                               product_name  aisle_id  department_id  prices  \
# 0                                     Soda        77              7     9.0
# ...

# %%
df_prods_merged = df_prods_merged.drop(columns=['busiest_period_of_day']) #delete error

# %% [markdown]
# # Export

# %%
df_prods_merged.to_pickle(os.path.join(path, 'Prepared Data', 'merged_4.7.pkl'))
