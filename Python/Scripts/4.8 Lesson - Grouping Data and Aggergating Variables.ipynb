# %% [markdown]
# # Importing Data

# %%
# import libraries
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\Oa\Career Foundry\Data'

# %%
df_ords_prods_merge = pd.read_pickle(os.path.join(path, 'Prepared Data', 'merged_4.7.pkl'))

# %%
df_ords_prods_merge.shape
# Out:
# (32434212, 17)

# %%
df = df_ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 17)

# %%
df.groupby('product_name')

# %%
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                14.794722
# 2                17.091743
# 3                17.930716
# 4                17.892234
# 5                15.211405
# 6                15.382228
# 7                17.699986
# 8                16.485269
# 9                15.965921
# 10               20.091818
# 11               16.484907
# 12               15.615845
# 13               16.485279
# 14               17.499513
# 15               15.690354
# 16               18.005083
# 17               16.155822
# 18               19.606536
# 19               17.630640
# 20               17.138204
# 21               21.996844

# %%
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1     14.794722
# 2     17.091743
# 3     17.930716
# 4     17.892234
# 5     15.211405
# 6     15.382228
# 7     17.699986
# 8     16.485269
# 9     15.965921
# 10    20.091818
# 11    16.484907
# 12    15.615845
# 13    16.485279
# 14    17.499513
# 15    15.690354
# 16    18.005083
# 17    16.155822
# 18    19.606536
# 19    17.630640
# 20    17.138204
# 21    21.996844
# Name: order_number, dtype: float64

# %%
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                14.794722   1  99
# 2                17.091743   1  98
# 3                17.930716   1  99
# 4                17.892234   1  99
# 5                15.211405   1  99
# 6                15.382228   1  99
# 7                17.699986   1  99
# 8                16.485269   1  91
# 9                15.965921   1  99
# 10               20.091818   1  99
# 11               16.484907   1  99
# 12               15.615845   1  99
# 13               16.485279   1  99
# 14               17.499513   1  99
# 15               15.690354   1  99
# 16               18.005083   1  99
# 17               16.155822   1  99
# 18               19.606536   1  99
# 19               17.630640   1  99
# 20               17.138204   1  99
# 21               21.996844   1  97

# %%
df_ords_prods_merge['max_order'] = df_ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# C:\Users\Oa\AppData\Local\Temp\ipykernel_17720\136815596.py:1: FutureWarning: The provided callable <function max at 0x00000139B5DACC20> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   df_ords_prods_merge['max_order'] = df_ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
df_ords_prods_merge.head(200)
# Out:
#      order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0     2539329        1             1          2                  8
# 1     2539329        1             1          2                  8
# 2     2539329        1             1          2                  8
# 3     2539329        1             1          2                  8
# 4     2539329        1             1          2                  8
# ..        ...      ...           ...        ...                ...
# 195   1402090        2            11          1                 10
# 196   1402090        2            11          1                 10
# 197   1402090        2            11          1                 10
# 198   1402090        2            11          1                 10
# 199   1402090        2            11          1                 10
#
#      days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                       NaN         196                  1          0
# 1                       NaN       14084                  2          0
# 2                       NaN       12427                  3          0
# 3                       NaN       26088                  4          0
# 4                       NaN       26405                  5          0
# ..                      ...         ...                ...        ...
# 195                    30.0       32792                  1          1
# 196                    30.0        4071                  2          0
# 197                    30.0       19051                  3          1
# 198                    30.0       19156                  4          1
# 199                    30.0       18523                  5          1
#
#                                           product_name  aisle_id  \
# 0                                                 Soda        77
# 1              Organic Unsweetened Vanilla Almond Milk        91
# 2                                  Original Beef Jerky        23
# 3                           Aged White Cheddar Popcorn        23
# 4                     XL Pick-A-Size Paper Towel Rolls        54
# ..                                                 ...       ...
# 195                     Chipotle Beef & Pork Realstick        23
# 196                    Organic Lemongrass Ginger Ramen        66
# 197               Pita Chips, Simply Naked, Party Size       107
# 198                          Fat Free Blueberry Yogurt       120
# 199  Total 2% All Natural Greek Strained Yogurt wit...       120
#
#      department_id  prices _merge    price_range_loc    busiest_days  \
# 0                7     9.0   both  Mid-range product  Regularly busy
# 1               16    12.5   both  Mid-range product  Regularly busy
# 2               19     4.4   both  Low-range product  Regularly busy
# 3               19     4.7   both  Low-range product  Regularly busy
# 4               17     1.0   both  Low-range product  Regularly busy
# ..             ...     ...    ...                ...             ...
# 195             19     5.2   both  Mid-range product  Regularly busy
# 196              6    11.6   both  Mid-range product  Regularly busy
# 197             19     3.9   both  Low-range product  Regularly busy
# 198             16    13.3   both  Mid-range product  Regularly busy
# 199             16    10.0   both  Mid-range product  Regularly busy
#
#     busiest_period_of_day  max_order
# 0          Average orders         10
# 1          Average orders         10
# 2          Average orders         10
# 3          Average orders         10
# 4          Average orders         10
# ..                    ...        ...
# 195           Most orders         14
# 196           Most orders         14
# 197           Most orders         14
# 198           Most orders         14
# 199           Most orders         14
#
# [200 rows x 18 columns]

# %%
pd.options.display.max_rows = None

# %%
df_ords_prods_merge.head(10)
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2539329        1             1          2                  8
# 2   2539329        1             1          2                  8
# 3   2539329        1             1          2                  8
# 4   2539329        1             1          2                  8
# 5   2398795        1             2          3                  7
# 6   2398795        1             2          3                  7
# 7   2398795        1             2          3                  7
# 8   2398795        1             2          3                  7
# 9   2398795        1             2          3                  7
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                     NaN       14084                  2          0
# 2                     NaN       12427                  3          0
# 3                     NaN       26088                  4          0
# 4                     NaN       26405                  5          0
# 5                    15.0         196                  1          1
# 6                    15.0       10258                  2          0
# 7                    15.0       12427                  3          1
# 8                    15.0       13176                  4          0
# 9                    15.0       26088                  5          1
#
#                               product_name  aisle_id  department_id  prices  \
# 0                                     Soda        77              7     9.0
# 1  Organic Unsweetened Vanilla Almond Milk        91             16    12.5
# 2                      Original Beef Jerky        23             19     4.4
# 3               Aged White Cheddar Popcorn        23             19     4.7
# 4         XL Pick-A-Size Paper Towel Rolls        54             17     1.0
# 5                                     Soda        77              7     9.0
# 6                               Pistachios       117             19     3.0
# 7                      Original Beef Jerky        23             19     4.4
# 8                   Bag of Organic Bananas        24              4    10.3
# 9               Aged White Cheddar Popcorn        23             19     4.7
#
#   _merge    price_range_loc    busiest_days busiest_period_of_day  max_order
# 0   both  Mid-range product  Regularly busy        Average orders         10
# 1   both  Mid-range product  Regularly busy        Average orders         10
# 2   both  Low-range product  Regularly busy        Average orders         10
# 3   both  Low-range product  Regularly busy        Average orders         10
# 4   both  Low-range product  Regularly busy        Average orders         10
# 5   both  Mid-range product  Regularly busy        Average orders         10
# 6   both  Low-range product  Regularly busy        Average orders         10
# 7   both  Low-range product  Regularly busy        Average orders         10
# 8   both  Mid-range product  Regularly busy        Average orders         10
# 9   both  Low-range product  Regularly busy        Average orders         10

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
df_ords_prods_merge.loc[(df_ords_prods_merge['max_order'] <= 40) & (df_ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'
df_ords_prods_merge.loc[df_ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
df_ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15891077
# Loyal customer      10293737
# New customer         6249398
# Name: count, dtype: int64

# %%
df_ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             1
# 2         1      New customer             1
# 3         1      New customer             1
# 4         1      New customer             1
# 5         1      New customer             2
# 6         1      New customer             2
# 7         1      New customer             2
# 8         1      New customer             2
# 9         1      New customer             2
# 10        1      New customer             2
# 11        1      New customer             3
# 12        1      New customer             3
# 13        1      New customer             3
# 14        1      New customer             3
# 15        1      New customer             3
# 16        1      New customer             4
# 17        1      New customer             4
# 18        1      New customer             4
# 19        1      New customer             4
# 20        1      New customer             4
# 21        1      New customer             5
# 22        1      New customer             5
# 23        1      New customer             5
# 24        1      New customer             5
# 25        1      New customer             5
# 26        1      New customer             5
# 27        1      New customer             5
# 28        1      New customer             5
# 29        1      New customer             6
# 30        1      New customer             6
# 31        1      New customer             6
# 32        1      New customer             6
# 33        1      New customer             7
# 34        1      New customer             7
# 35        1      New customer             7
# 36        1      New customer             7
# 37        1      New customer             7
# 38        1      New customer             8
# 39        1      New customer             8
# 40        1      New customer             8
# 41        1      New customer             8
# 42        1      New customer             8
# 43        1      New customer             8
# 44        1      New customer             9
# 45        1      New customer             9
# 46        1      New customer             9
# 47        1      New customer             9
# 48        1      New customer             9
# 49        1      New customer             9
# 50        1      New customer            10
# 51        1      New customer            10
# 52        1      New customer            10
# 53        1      New customer            10
# 54        1      New customer            10
# 55        1      New customer            10
# 56        1      New customer            10
# 57        1      New customer            10
# 58        1      New customer            10
# 59        2  Regular customer             1
